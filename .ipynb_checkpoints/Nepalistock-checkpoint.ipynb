# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('stockmarket.csv')
df
# Out:
#            Date  nepse open  nepse high  nepse Low  nepse close  nepse volume  \
# 0     7/20/1997      173.26      173.26     173.26       173.26             0
# 1     7/21/1997      173.25      173.25     173.25       173.25             0
# 2     7/22/1997      173.03      173.03     173.03       173.03             0
# 3     7/23/1997      172.68      173.03     173.03       173.03             0
# 4     7/24/1997      172.66      172.66     172.66       172.66             0
# ...         ...         ...         ...        ...          ...           ...
# 5512  7/18/2021     2892.47     2980.61    2892.47      2980.61   11638126493
# 5513  7/19/2021     3003.47     3031.87    2981.91      2994.58   11813754607
# 5514  7/20/2021     3005.43     3005.43    2975.71      2985.57    7897594269
# 5515  7/22/2021     2990.90     3018.27    2987.45      3004.31   11114121616
# 5516  7/25/2021     3017.56     3058.63    3017.56      3058.63   14302365148
#
# ...

# %%
#i think, date lai index banayo vane sajilo huncha
df.set_index('Date',inplace=True)
df
# Out:
#            nepse open  nepse high  nepse Low  nepse close  nepse volume  \
# Date
# 7/20/1997      173.26      173.26     173.26       173.26             0
# 7/21/1997      173.25      173.25     173.25       173.25             0
# 7/22/1997      173.03      173.03     173.03       173.03             0
# 7/23/1997      172.68      173.03     173.03       173.03             0
# 7/24/1997      172.66      172.66     172.66       172.66             0
# ...               ...         ...        ...          ...           ...
# 7/18/2021     2892.47     2980.61    2892.47      2980.61   11638126493
# 7/19/2021     3003.47     3031.87    2981.91      2994.58   11813754607
# 7/20/2021     3005.43     3005.43    2975.71      2985.57    7897594269
# 7/22/2021     2990.90     3018.27    2987.45      3004.31   11114121616
# 7/25/2021     3017.56     3058.63    3017.56      3058.63   14302365148
#
#              Date__1  weekday  weeknum  weeknumber  month  uniquemonth  \
# Date
# ...

# %%
df.describe()
# Out:
#         nepse open   nepse high    nepse Low  nepse close  nepse volume  \
# count  5517.000000  5517.000000  5517.000000  5517.000000  5.517000e+03
# mean    702.013270   704.339286   699.300509   701.732853  3.836268e+08
# std     555.173634   559.297190   549.778287   554.376357  1.515485e+09
# min     156.430000   156.430000   156.430000   156.430000  0.000000e+00
# 25%     281.060000   281.060000   281.060000   281.060000  0.000000e+00
# 50%     486.190000   486.190000   486.190000   486.190000  0.000000e+00
# 75%    1072.940000  1072.940000  1072.940000  1072.940000  0.000000e+00
# max    3061.810000  3063.060000  3017.560000  3058.630000  1.955017e+10
#
#            weekday      weeknum   weeknumber        month  uniquemonth  \
# count  5517.000000  5517.000000  5517.000000  5517.000000  5517.000000
# mean      3.242161    27.189415     3.195759     6.537974   144.911727
# std       1.479401    15.088806     1.309901     3.452918    82.509344
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5517 entries, 7/20/1997 to 7/25/2021
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nepse open    5517 non-null   float64
#  1   nepse high    5517 non-null   float64
#  2   nepse Low     5517 non-null   float64
#  3   nepse close   5517 non-null   float64
#  4   nepse volume  5517 non-null   int64
#  5   Date__1       5517 non-null   object
#  6   weekday       5517 non-null   int64
#  7   weeknum       5517 non-null   int64
#  8   weeknumber    5517 non-null   int64
#  9   month         5517 non-null   int64
#  10  uniquemonth   5517 non-null   int64
#  11  uniqueweek    5517 non-null   int64
#  12  close-open    5517 non-null   float64
#  13  high-low      5517 non-null   float64
#  14  high-close    5517 non-null   float64
#  15  close-low     5517 non-null   float64
# dtypes: float64(8), int64(7), object(1)
# memory usage: 732.7+ KB

# %%
df['nepse high'].max()
# nepse ko high value
# Out:
# 3063.06

# %%
# kaile rahixa ta nepshe sabse high
df.iloc[df['nepse high'].argmax()]
# Out:
# nepse open               3061.81
# nepse high               3063.06
# nepse Low                3013.77
# nepse close               3022.1
# nepse volume         16528749739
# Date__1                  Tuesday
# weekday                        3
# weeknum                       25
# weeknumber                     3
# month                          6
# uniquemonth                  287
# uniqueweek                  1226
# close-open                -39.71
# high-low                   49.29
# high-close                 40.96
# close-low                   8.33
# returns                -0.001229
# cumilativeReturns      17.442572
# Name: 6/15/2021, dtype: object

# %%
df['nepse Low'].min()
# nepse ko low value
# Out:
# 156.43

# %%
df[df['nepse Low']==156.43]
# kaile raixa ta nepse sabse lowest
# Out:
#           nepse open  nepse high  nepse Low  nepse close  nepse volume  \
# Date
# 6/2/1998      156.43      156.43     156.43       156.43             0
#
#           Date__1  weekday  weeknum  weeknumber  month  uniquemonth  \
# Date
# 6/2/1998  Tuesday        3       23           1      6           12
#
#           uniqueweek  close-open  high-low  high-close  close-low   returns  \
# Date
# 6/2/1998          39         0.0       0.0         0.0        0.0 -0.002741
#
#           cumilativeReturns
# Date
# 6/2/1998           0.902863

# %%
plt.figure(figsize=(15,6))
df['nepse high'].plot()
plt.show()
# ahile samma high high huda kasto graph dekhinxa ta

# %%
# sabse highest volume karobar katiko vayo kahile vayo
df.iloc[df['nepse volume'].argmax()]
# Out:
# nepse open               2965.77
# nepse high                2983.1
# nepse Low                2957.33
# nepse close               2983.1
# nepse volume         19550166636
# Date__1                   Sunday
# weekday                        1
# weeknum                       25
# weeknumber                     3
# month                          6
# uniquemonth                  287
# uniqueweek                  1226
# close-open                 17.33
# high-low                   25.77
# high-close                   0.0
# close-low                  25.77
# returns                 0.013013
# cumilativeReturns      17.217477
# Name: 6/13/2021, dtype: object

# %%
plt.figure(figsize=(15,6))

df['nepse volume'].plot()
plt.show()

# %%
#2020 paxiko matra kde plot herna khojeko
df.iloc[5195:]['nepse volume'].plot(figsize=(15,10),kind="kde",color='g')

plt.show()

# %%
df['Date__1'].value_counts()
#this conclude that sanibar pani 2 din chai market open vayeko rahexa
# Out:
# Monday       1111
# Wednesday    1106
# Thursday     1101
# Tuesday      1095
# Sunday        835
# Friday        267
# Saturday        2
# Name: Date__1, dtype: int64

# %%
df[df['Date__1']=='Saturday']
#kaile kaile sanibar pani market open thyo ta
# Out:
#             nepse open  nepse high  nepse Low  nepse close  nepse volume  \
# Date
# 12/27/2003      202.23      202.23     202.23       202.23             0
# 9/8/2007        796.34      796.34     796.34       796.34             0
#
#              Date__1  weekday  weeknum  weeknumber  month  uniquemonth  \
# Date
# 12/27/2003  Saturday        7       52           4     12           78
# 9/8/2007    Saturday        7       36           2      9          123
#
#             uniqueweek  close-open  high-low  high-close  close-low
# Date
# 12/27/2003         329         0.0       0.0         0.0        0.0
# 9/8/2007           522         0.0       0.0         0.0        0.0

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 8), dpi=80)
plt.title("Nepal Whole stock price",fontsize=44,color="w")
df['nepse open'].plot(label="opening price")
df['nepse high'].plot(label="high price",color="r")
df['nepse Low'].plot(label="Low price")
df['nepse close'].plot(label="closing price",color='k')
plt.legend()
plt.show()

# %%
#variation aayeko xa vanne ,opening and closing price ma different dekhesi tha hunax
paxikodf=df.iloc[5297:]
#paxikodf
from matplotlib.pyplot import figure

figure(figsize=(12, 8), dpi=80)
plt.title("Nepal stock in 2020-9 to 2021-7",fontsize=44,color="w")
paxikodf['nepse open'].plot(label="opening price")
paxikodf['nepse high'].plot(label="high price",color="r")
paxikodf['nepse Low'].plot(label="Low price")
paxikodf['nepse close'].plot(label="closing price",color='b')
plt.legend()
plt.show()

# %%
#highest varance(close-open) in perticular date
df['close-open'].max()
# whole market value ko daily highest open close different high 92.55
# Out:
# 92.55

# %%
#highest uthal puthal(high-low) in perticular date
df['high-low'].max()
# whole market value ko daily highest high low different high 92.55
# Out:
# 121.87

# %%
paxikodf
# 2020 8 31 paxiko data haru
# Out:
#            nepse open  nepse high  nepse Low  nepse close  nepse volume  \
# Date
# 8/31/2020     1466.57     1489.01    1466.57      1484.99    3462586125
# 9/2/2020      1509.40     1519.78    1499.72      1510.57    4181036115
# 9/3/2020      1524.19     1524.67    1497.47      1510.42    2634886231
# 9/6/2020      1538.42     1538.42    1494.97      1499.97    2782377887
# 9/7/2020      1503.37     1503.37    1483.65      1487.81    2164930214
# ...               ...         ...        ...          ...           ...
# 7/18/2021     2892.47     2980.61    2892.47      2980.61   11638126493
# 7/19/2021     3003.47     3031.87    2981.91      2994.58   11813754607
# 7/20/2021     3005.43     3005.43    2975.71      2985.57    7897594269
# 7/22/2021     2990.90     3018.27    2987.45      3004.31   11114121616
# 7/25/2021     3017.56     3058.63    3017.56      3058.63   14302365148
#
#              Date__1  weekday  weeknum  weeknumber  month  uniquemonth  \
# Date
# ...

# %%
#daily percentage change
df['returns']=(df['nepse close']/df['nepse close'].shift(1))-1

# %%
df['returns']
# Out:
# Date
# 7/20/1997         NaN
# 7/21/1997   -0.000058
# 7/22/1997   -0.001270
# 7/23/1997    0.000000
# 7/24/1997   -0.002138
#                ...
# 7/18/2021    0.033721
# 7/19/2021    0.004687
# 7/20/2021   -0.003009
# 7/22/2021    0.006277
# 7/25/2021    0.018081
# Name: returns, Length: 5517, dtype: float64

# %%
df['returns'].hist(bins=200)
# good lagxa if normal distribution jasto vaye
# Out:
# <AxesSubplot:>

# %%
df['returns'].plot(kind="kde")
plt.show()

# %%
#cumilative returns
df["cumilativeReturns"]=(1+ df['returns']).cumprod()
df.tail(5)
# Out:
#            nepse open  nepse high  nepse Low  nepse close  nepse volume  \
# Date
# 7/18/2021     2892.47     2980.61    2892.47      2980.61   11638126493
# 7/19/2021     3003.47     3031.87    2981.91      2994.58   11813754607
# 7/20/2021     3005.43     3005.43    2975.71      2985.57    7897594269
# 7/22/2021     2990.90     3018.27    2987.45      3004.31   11114121616
# 7/25/2021     3017.56     3058.63    3017.56      3058.63   14302365148
#
#             Date__1  weekday  weeknum  weeknumber  month  uniquemonth  \
# Date
# 7/18/2021    Sunday        1       30           4      7          288
# 7/19/2021    Monday        2       30           4      7          288
# 7/20/2021   Tuesday        3       30           4      7          288
# 7/22/2021  Thursday        5       30           4      7          288
# 7/25/2021    Sunday        1       31           5      7          288
#
#            uniqueweek  close-open  high-low  high-close  close-low   returns  \
# Date
# ...

# %%
df["cumilativeReturns"].plot(figsize=(15,10))

plt.show()
# this gives =>if we invest Rs 1  at begining then it will returns Rs 17.65 today

# %% [markdown]
# # This is not a good data to make prediction for tomorrow's price , Here you can only guess it through graph.
